# %%
import torch
import os
torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# device(type='cuda')

# %%
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:21"
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
tqdm.pandas()
from sentence_transformers import SentenceTransformer, models, InputExample, losses
from datasets import Dataset
from torch.utils.data import DataLoader
from sklearn.model_selection import KFold
import re

# %%
DATA_PATH = "data/"
topics = pd.read_csv(DATA_PATH + "topics.csv")
content = pd.read_csv(DATA_PATH + "content.csv")
correlations = pd.read_csv('data/kfold_correlations.csv')
correlations = correlations[correlations.fold != 0]

# %%
correlations
# Out:
#              topic_id                                        content_ids  fold
# 0      t_00004da3a1b2  c_1108dd0c7a5d c_376c5a8eb028 c_5bc0e1e2cba0 c...     1
# 1      t_00068291e9a4  c_639ea2ef9c95 c_89ce9367be10 c_ac1672cdcd2c c...     1
# 2      t_00069b63a70a                                     c_11a1dc0bfb99     4
# 3      t_0006d41a73a8  c_0c6473c3480d c_1c57a1316568 c_5e375cf14c47 c...     2
# 5      t_0008a1bd84ba                      c_7ff92a954a3d c_8790b074383e     3
# ...               ...                                                ...   ...
# 61512  t_fff830472691                      c_61fb63326e5d c_8f224e321c87     1
# 61513  t_fff9e5407d13  c_026db653a269 c_0fb048a6412c c_20de77522603 c...     4
# 61514  t_fffbe1d5d43c                      c_46f852a49c08 c_6659207b25d5     2
# 61515  t_fffe14f1be1e                                     c_cece166bad6a     2
# 61516  t_fffe811a6da9                                     c_92b8fad372ee     3
#
# [49213 rows x 3 columns]

# %%
correlations["content_id"] = correlations["content_ids"].str.split(" ")
corr = correlations.explode("content_id").drop(columns=["content_ids"])

# %%
topics.rename(columns=lambda x: "topic_" + x, inplace=True)
content.rename(columns=lambda x: "content_" + x, inplace=True)

# %%
corr = corr.merge(topics, how="left", on="topic_id")
corr = corr.merge(content, how="left", on="content_id")
corr.head()
# Out:
#          topic_id  fold      content_id                      topic_title  \
# 0  t_00004da3a1b2     1  c_1108dd0c7a5d       Откриването на резисторите
# 1  t_00004da3a1b2     1  c_376c5a8eb028       Откриването на резисторите
# 2  t_00004da3a1b2     1  c_5bc0e1e2cba0       Откриването на резисторите
# 3  t_00004da3a1b2     1  c_76231f9d0b5e       Откриването на резисторите
# 4  t_00068291e9a4     1  c_639ea2ef9c95  Entradas e saídas de uma função
#
#                                    topic_description topic_channel  \
# 0  Изследване на материали, които предизвикват на...        000cf7
# 1  Изследване на материали, които предизвикват на...        000cf7
# 2  Изследване на материали, които предизвикват на...        000cf7
# 3  Изследване на материали, които предизвикват на...        000cf7
# 4               Entenda um pouco mais sobre funções.        8e286a
#
#   topic_category  topic_level topic_language    topic_parent  \
# 0         source            4             bg  t_16e29365b50d
# 1         source            4             bg  t_16e29365b50d
# 2         source            4             bg  t_16e29365b50d
# 3         source            4             bg  t_16e29365b50d
# 4         source            4             pt  t_d14b6c2a2b70
#
#    topic_has_content                                      content_title  \
# 0               True                                Молив като резистор
# 1               True                 Да чуем променливото съпротивление
# 2               True     Променлив резистор (реостат) с графит от молив
# 3               True  Последователно свързване на галваничен елемент...
# 4               True            Dados e resultados de funções: gráficos
#
#                                  content_description content_kind  \
# 0  Моливът причинява промяна в отклонението, подо...        video
# 1  Тук чертаем линия на лист хартия и я използвам...        video
# 2  Използваме сърцевината на молива (неговия граф...        video
# 3  Защо отклонението се променя, когато се свърже...        video
# 4  Encontre todas as entradas que correspondem a ...     exercise
#
#   content_text content_language content_copyright_holder content_license
# 0          NaN               bg                      NaN             NaN
# 1          NaN               bg                      NaN             NaN
# 2          NaN               bg                      NaN             NaN
# 3          NaN               bg                      NaN             NaN
# 4          NaN               pt                      NaN             NaN

# %%
#corr = corr.drop_duplicates(subset = ['topic_title','content_title'])

# %%
corr['topic_title'].fillna("", inplace = True)
corr['content_title'].fillna("", inplace = True)

corr['topic_description'].fillna("no description", inplace = True)
corr['content_description'].fillna("no description", inplace = True)

corr['content_text'].fillna("", inplace = True)
corr['content_license'].fillna("", inplace = True)

# %% [raw]
# [CLS] dominio disperso durante el ano : gente importante <|=t_sep=|> los siguientes materiales estan disponibles para el ela de prekindergarten. dominio de personas importantes : guia para el profesor paginas de actividades de libros con rotafolios tarjetas de imagenes canciones infantiles y canciones posters <|=t_sep=|> prekindergarten artes del lenguaje en ingles | engageny ( es ) | escuchar y aprender strand <|=t_sep=|> para ayudar [SEP]

# %%
def white_spaces(x):
    return re.sub(' +', ' ', x)

corr['text1'] =  '[CLS] ' + corr['topic_title'] + ' <|=t_sep=|> '  + corr['topic_description'] + ' [SEP]'
corr['text2'] = '[CLS] ' + corr['content_title'] + ' <|=t_sep=|> '  + corr['topic_description'] + ' <|=t_sep=|> ' + corr['content_text'] + ' <|=t_sep=|> ' + corr['content_kind'] + ' [SEP]'
#corr['text1'] = corr['text1'].progress_apply(lambda x: white_spaces(x))
#corr['text2'] = corr['text2'].progress_apply(lambda x: white_spaces(x))

# %%
corr
# Out:
#               topic_id  fold      content_id  \
# 0       t_00004da3a1b2     1  c_1108dd0c7a5d
# 1       t_00004da3a1b2     1  c_376c5a8eb028
# 2       t_00004da3a1b2     1  c_5bc0e1e2cba0
# 3       t_00004da3a1b2     1  c_76231f9d0b5e
# 4       t_00068291e9a4     1  c_639ea2ef9c95
# ...                ...   ...             ...
# 223824  t_fff9e5407d13     4  c_d64037a72376
# 223825  t_fffbe1d5d43c     2  c_46f852a49c08
# 223826  t_fffbe1d5d43c     2  c_6659207b25d5
# 223827  t_fffe14f1be1e     2  c_cece166bad6a
# 223828  t_fffe811a6da9     3  c_92b8fad372ee
#
#                                               topic_title  \
# 0                              Откриването на резисторите
# 1                              Откриването на резисторите
# 2                              Откриването на резисторите
# 3                              Откриването на резисторите
# 4                         Entradas e saídas de uma função
# ...                                                   ...
# 223824                              NA_U06 - El periódico
# 223825                   Inscribed shapes problem solving
# 223826                   Inscribed shapes problem solving
# 223827                                          Lección 7
# 223828  تحديد العلاقة بين الإحداثيّات القطبية والإحداث...
#
#                                         topic_description topic_channel  \
# 0       Изследване на материали, които предизвикват на...        000cf7
# 1       Изследване на материали, които предизвикват на...        000cf7
# 2       Изследване на материали, които предизвикват на...        000cf7
# 3       Изследване на материали, които предизвикват на...        000cf7
# 4                    Entenda um pouco mais sobre funções.        8e286a
# ...                                                   ...           ...
# 223824                                     no description        71fd51
# 223825  Use properties of inscribed angles to prove pr...        0c929f
# 223826  Use properties of inscribed angles to prove pr...        0c929f
# 223827                                     no description        6e90a7
# 223828                           5b9e5ca86571f90499ea987f        9fd860
#
#        topic_category  topic_level topic_language    topic_parent  \
# 0              source            4             bg  t_16e29365b50d
# 1              source            4             bg  t_16e29365b50d
# 2              source            4             bg  t_16e29365b50d
# 3              source            4             bg  t_16e29365b50d
# 4              source            4             pt  t_d14b6c2a2b70
# ...               ...          ...            ...             ...
# 223824   supplemental            2             es  t_5bd8f6ae9f7d
# 223825         source            4             sw  t_50145b9bab3f
# 223826         source            4             sw  t_50145b9bab3f
# 223827        aligned            6             es  t_d448c707984d
# 223828         source            2             ar  t_5b4f3ba4eb7d
#
#         topic_has_content                                      content_title  \
# 0                    True                                Молив като резистор
# 1                    True                 Да чуем променливото съпротивление
# 2                    True     Променлив резистор (реостат) с графит от молив
# 3                    True  Последователно свързване на галваничен елемент...
# 4                    True            Dados e resultados de funções: gráficos
# ...                   ...                                                ...
# 223824               True                         Introducción: El periódico
# 223825               True  Proof: Right triangles inscribed in circles -d...
# 223826               True  Area of inscribed equilateral triangle -dubbed...
# 223827               True                             Juego con las palabras
# 223828               True                                            التقييم
#
#                                       content_description content_kind  \
# 0       Моливът причинява промяна в отклонението, подо...        video
# 1       Тук чертаем линия на лист хартия и я използвам...        video
# 2       Използваме сърцевината на молива (неговия граф...        video
# 3       Защо отклонението се променя, когато се свърже...        video
# 4       Encontre todas as entradas que correspondem a ...     exercise
# ...                                                   ...          ...
# 223824                                     no description        html5
# 223825  Proof showing that a triangle inscribed in a c...        video
# 223826  A worked example of finding the area of an equ...        video
# 223827                                     no description     document
# 223828                           5b0a30e7b42e8704a45b2bfd     exercise
#
#                                              content_text content_language  \
# 0                                                                       bg
# 1                                                                       bg
# 2                                                                       bg
# 3                                                                       bg
# 4                                                                       pt
# ...                                                   ...              ...
# 223824                                                                  es
# 223825                                                                  sw
# 223826                                                                  sw
# 223827                                                                  es
# 223828  كم سيكون حاصل الجداء السلمي لشعاعين متوازيين ؟...               ar
#
#        content_copyright_holder content_license  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...             ...
# 223824                      NaN
# 223825                      NaN
# 223826                      NaN
# 223827                      NaN
# 223828                   Edraak     CC BY-NC-SA
#
#                                                     text1  \
# 0       [CLS] Откриването на резисторите <|=t_sep=|> И...
# 1       [CLS] Откриването на резисторите <|=t_sep=|> И...
# 2       [CLS] Откриването на резисторите <|=t_sep=|> И...
# 3       [CLS] Откриването на резисторите <|=t_sep=|> И...
# 4       [CLS] Entradas e saídas de uma função <|=t_sep...
# ...                                                   ...
# 223824  [CLS] NA_U06 - El periódico <|=t_sep=|> no des...
# 223825  [CLS] Inscribed shapes problem solving <|=t_se...
# 223826  [CLS] Inscribed shapes problem solving <|=t_se...
# 223827   [CLS] Lección 7 <|=t_sep=|> no description [SEP]
# 223828  [CLS] تحديد العلاقة بين الإحداثيّات القطبية وا...
#
#                                                     text2
# 0       [CLS] Молив като резистор <|=t_sep=|> Изследва...
# 1       [CLS] Да чуем променливото съпротивление <|=t_...
# 2       [CLS] Променлив резистор (реостат) с графит от...
# 3       [CLS] Последователно свързване на галваничен е...
# 4       [CLS] Dados e resultados de funções: gráficos ...
# ...                                                   ...
# 223824  [CLS] Introducción: El periódico <|=t_sep=|> n...
# 223825  [CLS] Proof: Right triangles inscribed in circ...
# 223826  [CLS] Area of inscribed equilateral triangle -...
# 223827  [CLS] Juego con las palabras <|=t_sep=|> no de...
# 223828  [CLS] التقييم <|=t_sep=|> 5b9e5ca86571f90499ea...
#
# [223829 rows x 20 columns]

# %%
corr["set"] = corr[["text1", "text2"]].values.tolist()
train_df = pd.DataFrame(corr["set"])
#target = corr['target']

# %%
dataset = Dataset.from_pandas(train_df)

# %%
train_examples = []
train_data = dataset["set"] 
n_examples = dataset.num_rows

for i in tqdm(range(n_examples)):
    example = train_data[i]
    if example[0] == None: #remove None
        print(example)
        continue        
    train_examples.append(InputExample(texts=[str(example[0]), str(example[1])],
                                      # label=target[i]
                                      ))
# Out:
#   0%|          | 0/223829 [00:00<?, ?it/s]

# %% [markdown]
# from sentence_transformers import SentenceTransformer, models
# from torch import nn
#
# word_embedding_model = models.Transformer('sentence-transformers/paraphrase-multilingual-mpnet-base-v2', max_seq_length=64)
# pooling_model = models.Pooling(word_embedding_model.get_word_embedding_dimension())
# dense_model = models.Dense(in_features=pooling_model.get_sentence_embedding_dimension(), out_features=384, activation_function=nn.Tanh())
#
# model = SentenceTransformer(modules=[word_embedding_model, pooling_model, dense_model])

# %%
model = SentenceTransformer("sentence-transformers/paraphrase-multilingual-mpnet-base-v2")
tokens = ["<|=t_sep=|> "]
word_embedding_model = model._first_module()
word_embedding_model.tokenizer.add_tokens(tokens, special_tokens=True)
word_embedding_model.auto_model.resize_token_embeddings(len(word_embedding_model.tokenizer))
pooling_model = models.Pooling(word_embedding_model.get_word_embedding_dimension())
model = SentenceTransformer(modules=[word_embedding_model, pooling_model])
model.max_seq_length = 64

# %%
model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 64, 'do_lower_case': False}) with Transformer model: XLMRobertaModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
# )

# %% [raw]
# model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2",device='cuda')
# model.max_seq_length = 64
# tokens = ["[C1]", "[C2]","[C3]"]
# word_embedding_model = model._first_module()   #Your models.Transformer object
# word_embedding_model.tokenizer.add_tokens(tokens, special_tokens=True)
# word_embedding_model.auto_model.resize_token_embeddings(len(word_embedding_model.tokenizer))
# from torch import nn
# pooling_model = models.Pooling(word_embedding_model.get_word_embedding_dimension())
# dense_model = models.Dense(in_features=pooling_model.get_sentence_embedding_dimension(), out_features=384, activation_function=nn.Tanh())
#
# model = SentenceTransformer(modules=[word_embedding_model, pooling_model, dense_model])

# %%
#qmodel = torch.quantization.quantize_dynamic(model, {torch.nn.Linear}, dtype=torch.qint8)

# %%
train_dataloader = DataLoader(train_examples, shuffle=True, batch_size=32,num_workers=1)
train_loss = losses.MultipleNegativesRankingLoss(model=model)
# num_epochs = 10
num_epochs = 20
warmup_steps = int(len(train_dataloader) * num_epochs * 0.1) #10% of train data

# %%
model.fit(train_objectives=[(train_dataloader, train_loss)],
          epochs=num_epochs,
          show_progress_bar=True,
          use_amp = True,
          #gradient_checkpointing=True,
          save_best_model = True,
          #output_path='./paraphrase-multilingual-mpnet-base-v2-exp_fold0_epochs10',
          warmup_steps=warmup_steps
         )
# Out:
# Epoch:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/6995 [00:00<?, ?it/s]

# %%
model.save(f"model/paraphrase-multilingual-mpnet-base-v2-epochs-2.5-tuned/")

# %%
#model.save("models/all-MiniLM-L6-v2_fold0_epochs20/")
